# %%
import torch
from emrgpt.model import TokenStreamGPT
from emrgpt.data import TokenStreamDS

# %%
m = TokenStreamGPT.load('cache/TokenStreamGPT.ckpt')
m
# Out:
# TokenStreamGPT(
#   (embedding_table): Embedding(644, 512)
#   (memory_projection): Linear(in_features=22, out_features=512, bias=True)
#   (positional_encoding): FixedPositionalEncoding(
#     (dropout): Dropout(p=0.2, inplace=False)
#   )
#   (blocks): Sequential(
#     (0): AkDecoderBlock(
#       (self_attention): AkMultiHeadAttention(
#         (heads): ModuleList(
#           (0-5): 6 x AkSelfAttentionHead(
#             (key): Linear(in_features=512, out_features=85, bias=False)
#             (query): Linear(in_features=512, out_features=85, bias=False)
#             (value): Linear(in_features=512, out_features=85, bias=False)
#             (dropout): Dropout(p=0.2, inplace=False)
#           )
#         )
#         (proj): Linear(in_features=510, out_features=512, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#       )
#       (feedforward): FeedForward(
#         (net): Sequential(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
# ...

# %%
ds = TokenStreamDS(block_size=m.conf.block_size, testset=True)
ds
# Out:
# Initiated dataset with:
# 	ICU stays: 84951
# 	Vocab size: 644
# 	Block size: 512
